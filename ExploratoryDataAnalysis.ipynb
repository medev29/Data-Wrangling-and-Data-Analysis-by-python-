# %%
import pandas as pd

# %%
import requests

def download(url, filename):
    response = requests.get(url)
    if response.status_code == 200:
        with open(filename, 'wb') as f:
            f.write(response.content)

# %%
download('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv', 'm2_survey_data.csv')
file_name = "m2_survey_data.csv"

# %%
df = pd.read_csv(file_name)

# %%
df.head()
# Out:
#    Respondent                      MainBranch Hobbyist  \
# 0           4  I am a developer by profession       No
# 1           9  I am a developer by profession      Yes
# 2          13  I am a developer by profession      Yes
# 3          16  I am a developer by profession      Yes
# 4          17  I am a developer by profession      Yes
#
#                                          OpenSourcer  \
# 0                                              Never
# 1                         Once a month or more often
# 2  Less than once a month but more than once per ...
# 3                                              Never
# 4  Less than once a month but more than once per ...
#
#                                           OpenSource          Employment  \
# 0  The quality of OSS and closed source software ...  Employed full-time
# 1  The quality of OSS and closed source software ...  Employed full-time
# 2  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# ...

# %%
print(df.columns.tolist())
# Out:
# ['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith', 'DatabaseDesireNextYear', 'PlatformWorkedWith', 'PlatformDesireNextYear', 'WebFrameWorkedWith', 'WebFrameDesireNextYear', 'MiscTechWorkedWith', 'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers', 'BlockchainOrg', 'BlockchainIs', 'BetterLife', 'ITperson', 'OffOn', 'SocialMedia', 'Extraversion', 'ScreenName', 'SOVisit1st', 'SOVisitFreq', 'SOVi
# ...

# %%
print(df['ConvertedComp'].head())
# Out:
# 0     61000.0
# 1     95179.0
# 2     90000.0
# 3    455352.0
# 4     65277.0
# Name: ConvertedComp, dtype: float64

# %%
print(df['ConvertedComp'].head())
print(df['ConvertedComp'].describe())
# Out:
# 0     61000.0
# 1     95179.0
# 2     90000.0
# 3    455352.0
# 4     65277.0
# Name: ConvertedComp, dtype: float64
# count    1.058200e+04
# mean     1.315967e+05
# std      2.947865e+05
# min      0.000000e+00
# 25%      2.686800e+04
# 50%      5.774500e+04
# 75%      1.000000e+05
# max      2.000000e+06
# Name: ConvertedComp, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plot the log-transformed data to handle extreme outliers
plt.figure(figsize=(10, 6))
sns.histplot(np.log(df['ConvertedComp'] + 1), kde=True)  # Add 1 to avoid log(0)
plt.title('Log-Transformed Distribution of Converted Compensation (USD)', fontsize=16)
plt.xlabel('Log of Converted Compensation (USD)', fontsize=12)
plt.ylabel('Density', fontsize=12)

plt.show()

# %%
#Plot the distribution curve for the column ConvertedComp.
df = df.dropna(subset=['ConvertedComp'])

plt.figure(figsize=(10, 6))  
sns.histplot(df['ConvertedComp'], kde=True)
plt.title('Distribution of Converted Compensation (USD)', fontsize=16)
plt.xlabel('Converted Compensation (USD)', fontsize=12)
plt.ylabel('Density', fontsize=12)
plt.show()

# %%
#Plot the histogram for the column ConvertedComp.
df = df.dropna(subset=['ConvertedComp'])
plt.figure(figsize=(10, 6))
sns.histplot(df['ConvertedComp'], bins=30)  
plt.title('Histogram of Converted Compensation (USD)', fontsize=16)
plt.xlabel('Converted Compensation (USD)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.show()

# %%
# the median of the column ConvertedComp
median_converted_comp = df['ConvertedComp'].median()
print(median_converted_comp)
# Out:
# 57745.0

# %%
#How many responders identified themselves only as a Man?
df = df.dropna(subset=['Gender'])
man_responders = df[df['Gender'] == 'Man']
num_man_responders = man_responders.shape[0]
print(num_man_responders)
# Out:
# 9725

# %%
#median ConvertedComp of responders identified themselves only as a Woman
df = df.dropna(subset=['Gender', 'ConvertedComp'])
woman_responders = df[df['Gender'] == 'Woman']
median_woman_converted_comp = woman_responders['ConvertedComp'].median()
print(median_woman_converted_comp)
# Out:
# 57708.0

# %%
#Give the five number summary for the column Age
df = df.dropna(subset=['Age'])
min_age = df['Age'].min()
q1_age = df['Age'].quantile(0.25)
median_age = df['Age'].median()
q3_age = df['Age'].quantile(0.75)
max_age = df['Age'].max()
print(f"Five-Number Summary for Age:\n")
print(f"Min: {min_age}")
print(f"Q1 (25th percentile): {q1_age}")
print(f"Median: {median_age}")
print(f"Q3 (75th percentile): {q3_age}")
print(f"Max: {max_age}")
# Out:
# Five-Number Summary for Age:
#
# Min: 16.0
# Q1 (25th percentile): 25.0
# Median: 29.0
# Q3 (75th percentile): 35.0
# Max: 99.0

# %%
#Plot a histogram of the column Age
plt.figure(figsize=(10, 6))
sns.histplot(df['Age'], bins=30, kde=False)
plt.title('Histogram of Age', fontsize=16)
plt.xlabel('Age', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.show()

# %%
#Find out if outliers exist in the column ConvertedComp using a box plot
df = df.dropna(subset=['ConvertedComp'])

plt.figure(figsize=(12, 6))
sns.boxplot(x=df['ConvertedComp'])
plt.title('Box Plot of Converted Compensation (USD)', fontsize=16)
plt.xlabel('Converted Compensation (USD)', fontsize=15)
plt.show()

# %%
#Find out the Inter Quartile Range for the column ConvertedComp
q1 = df['ConvertedComp'].quantile(0.25)
q3 = df['ConvertedComp'].quantile(0.75)
iqr = q3 - q1
print(iqr)
# Out:
# 73192.0

# %%
#Find out the upper and lower bounds.
print(f"The upper bound is: {upper_bound}")
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr
print(lower_bound,upper_bound)
# Out:
# The upper bound is: 207407.5
# -82980.0 209788.0

# %%
print(f"The lower bound is: {lower_bound}")
print(f"The upper bound is: {upper_bound}")
# Out:
# The lower bound is: -82980.0
# The upper bound is: 209788.0

# %%
#Identify how many outliers are there in the ConvertedComp column
outliers = df[(df['ConvertedComp'] < lower_bound) | (df['ConvertedComp'] > upper_bound)]
num_outliers = outliers.shape[0]
print(num_outliers)
# Out:
# 857

# %%
#Create a new dataframe by removing the outliers from the ConvertedComp column.
df = df.dropna(subset=['ConvertedComp'])
q1 = df['ConvertedComp'].quantile(0.25)
q3 = df['ConvertedComp'].quantile(0.75)
iqr = q3 - q1
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr
df_no_outliers = df[(df['ConvertedComp'] >= lower_bound) & (df['ConvertedComp'] <= upper_bound)]
print(df_no_outliers)
# Out:
#        Respondent                      MainBranch Hobbyist  \
# 0               4  I am a developer by profession       No
# 1               9  I am a developer by profession      Yes
# 2              13  I am a developer by profession      Yes
# 4              17  I am a developer by profession      Yes
# 5              19  I am a developer by profession      Yes
# ...           ...                             ...      ...
# 11392       25134  I am a developer by profession      Yes
# 11393       25136  I am a developer by profession      Yes
# 11394       25137  I am a developer by profession      Yes
# 11395       25138  I am a developer by profession      Yes
# 11396       25141  I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# 0                                                  Never
# 1                             Once a month or more often
# 2      Less than once a month but more than once per ...
# ...

# %%
df_no_outliers.shape[0]
# Out:
# 9432

# %%
f = df.dropna(subset=['ConvertedComp'])
q1 = df['ConvertedComp'].quantile(0.25)
q3 = df['ConvertedComp'].quantile(0.75)
iqr = q3 - q1
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr
df_no_outliers = df[(df['ConvertedComp'] >= lower_bound) & (df['ConvertedComp'] <= upper_bound)]
print(f"The new DataFrame without outliers has {df_no_outliers.shape[0]} rows.")
# Out:
# The new DataFrame without outliers has 9432 rows.

# %%
print(df.head())
print(df.columns)
print(df.dtypes)
# Out:
#    Respondent                      MainBranch Hobbyist  \
# 1           9  I am a developer by profession      Yes
# 2          13  I am a developer by profession      Yes
# 3          16  I am a developer by profession      Yes
# 4          17  I am a developer by profession      Yes
# 5          19  I am a developer by profession      Yes
#
#                                          OpenSourcer  \
# 1                         Once a month or more often
# 2  Less than once a month but more than once per ...
# 3                                              Never
# 4  Less than once a month but more than once per ...
# 5                                              Never
#
#                                           OpenSource          Employment  \
# 1  The quality of OSS and closed source software ...  Employed full-time
# 2  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 3  The quality of OSS and closed source software ...  Employed full-time
# ...

# %%
df = df.dropna(subset=['Age', 'ConvertedComp', 'YearsCode', 'YearsCodePro', 'WorkWeekHrs'])
# Convert relevant columns to numeric, coercing errors to NaN
numeric_columns = ['ConvertedComp', 'YearsCode', 'YearsCodePro', 'WorkWeekHrs']
df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric, errors='coerce')

# %%
df = df.dropna(subset=numeric_columns)

# %%
numeric_df = df.select_dtypes(include=['number'])
# Drop rows with missing values in numeric columns
numeric_df = numeric_df.dropna()

# %%
correlation_matrix = numeric_df.corr()

# %%
age_correlation = correlation_matrix['Age']
print(age_correlation)
# Out:
# Respondent       0.005325
# YearsCode        0.799125
# YearsCodePro     0.843557
# CompTotal        0.007122
# ConvertedComp    0.101620
# WorkWeekHrs      0.026833
# CodeRevHrs      -0.014228
# Age              1.000000
# Name: Age, dtype: float64
